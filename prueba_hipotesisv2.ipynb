# %% [markdown]
# ## **Ejercicio 1**

# %% [markdown]
# Usted es un nutricionista que investiga dos tipos diferentes de dietas para ver si existe una diferencia significativa en la pérdida de peso después de un mes. Eliges dos grupos aleatorios de personas; un grupo sigue la primera dieta y el otro sigue la segunda. Al final del mes, se registra la pérdida de peso (en kg) de cada persona:
#
# | Diet 1 | Diet 2 |
# |:-------|:-------|
# | 2.0 | 3.0 |
# | 2.5 | 3.2 |
# | 3.0 | 3.1 |
# | 2.8 | 2.9 |
# | 2.3 | 2.8 |
# | 2.7 | 3.0 |
# | 2.5 | 3.2 |
#
# Con estos datos se busca responder a la siguiente pregunta: ¿Existe una diferencia significativa en la pérdida de peso promedio entre las personas que siguieron la primera dieta y las que siguieron la segunda dieta?   sacar conclusiones, siga los siguientes puntos:
#
# -Enunciar la hipóParatesis: hipótesis nula y alternativa.
# -Realizar la prueba para comprobar la hipótesis. Puede utilizar la prueba t de Student.
# -Analizar las conclusiones.

# %% [markdown]
# Hipotesis Nula: No hay diferencia en la pérdida de peso promedio entre las dos dietas.
# Hipótesis alternativa: Sí hay una diferencia en la pérdida de peso promedio

# %% [markdown]
# ## Importaciones

# %%
import scipy.stats as stats
from statsmodels.stats.multicomp import pairwise_tukeyhsd
import numpy as np
from scipy.stats import shapiro, levene, f_oneway

# %%
diet_1 = [2.0, 2.5, 3.0, 2.8, 2.3, 2.7, 2.5]
diet_2 = [3.0, 3.2, 3.1, 2.9, 2.8, 3.0, 3.2]

# %% [markdown]
# ## Verificar Normalidad.- Si p > 0.05 es Normal. El p-value = 0.96 y 0.59 son bastante normales.

# %%
print(shapiro(diet_1))
print(shapiro(diet_2))
# Out:
# ShapiroResult(statistic=np.float64(0.9808454935519088), pvalue=np.float64(0.9635409177367069))
# ShapiroResult(statistic=np.float64(0.934584156825349), pvalue=np.float64(0.5905246580529597))

# %% [markdown]
# ## Verificar Igualdad de varianzas.- Si p > 0.05 se asume igualdad de varianzas. p es 0.15 se verifica igualdad de varianzas.

# %%
print("Levene:", levene(diet_1, diet_2))
# Out:
# Levene: LeveneResult(statistic=np.float64(2.2710280373831746), pvalue=np.float64(0.15767770055358))

# %% [markdown]
# ## T-Value. p<0.05: Hay Diferencia Significativa entre las dos dietas.

# %%
t_value= stats.ttest_ind(diet_1, diet_2, equal_var=False)

print(t_value)
# Out:
# TtestResult(statistic=np.float64(-3.5383407969933938), pvalue=np.float64(0.007125697852423989), df=np.float64(8.353880491389793))

# %% [markdown]
# ANOVA
#
# **ANOVA** (*Analysis of Variance - Análisis de variación*) Es una técnica estadística utilizada para comparar las medidas de dos o más grupos. La idea detrás de ANOVA es descomponer la variabilidad total de los datos en dos componentes: variabilidad entre grupos y variabilidad dentro de los grupos:
#
# - **Variabilidad entre grupos**: Esta variabilidad se refiere a las diferencias entre las medias del grupo. Si esta variabilidad es considerablemente mayor que la variabilidad dentro del grupo, podría ser una indicación de que al menos una de las medias del grupo es diferente.
# - **Variabilidad dentro del grupo**: Esta variabilidad se refiere a la dispersión de los datos dentro de cada grupo. Si todos los grupos tienen una variabilidad similar, entonces cualquier diferencia notable en las medias de los grupos podría considerarse significativa.
#
# Las hipótesis en ANOVA suelen incluir:
#
# - **Hipótesis nula** ($H₀$): Las medias de todos los grupos son iguales.
# - **Hipótesis alternativa** ($H₁$): Al menos una de las medias del grupo es diferente.
#
# Si el resultado de la prueba ANOVA es significativo (por ejemplo, un valor p inferior a un umbral como 0,05), esto sugiere que al menos la media de un grupo es diferente.

# %% [markdown]
# ## **Ejercicio 2**
#
# Un agricultor decide probar tres tipos diferentes de fertilizantes para determinar si alguno es superior en términos de producción de maíz. El agricultor planta maíz en 15 parcelas idénticas y utiliza los tres fertilizantes (5 parcelas para cada tipo). Al final de la temporada mide el rendimiento de maíz (en kg) de cada parcela, con el siguiente resultado:
#
# | Fertilizante 1 | Fertilizante 2 | Fertilizante 3 |
# |:-------------|:-------------|:-------------|
# | 20 | 22 | 24 |
# | 21 | 21 | 23 |
# | 20 | 23 | 22 |
# | 19 | 22 | 23 |
# | 20 | 21 | 24 |
#
# Con estos datos busca responder la siguiente pregunta: ¿Existe una diferencia significativa en el rendimiento promedio del maíz entre los tres tipos de fertilizantes?
#
# Para ayudarte, sigue los siguientes puntos:
#
# -Enunciar la hipótesis: hipótesis nula y alternativa.
# -Realizar la prueba ANOVA.
# -Analizar las conclusiones.
# -Si un fertilizante es mejor que otro, ¿cómo podemos saberlo?

# %% [markdown]
# Hipotesis Nula: Todos los fertilizantes producen el mismo rendimiento promedio.
# Hipotesis Alternativa: Al menos uno de los fertilizantes produce un rendimiento diferente.

# %%
fertilizer_1 = [20, 21, 20, 19, 20]
fertilizer_2 = [22, 21, 23, 22, 21]
fertilizer_3 = [24, 23, 22, 23, 24]

# %% [markdown]
# ## Verificar Normalidad. Si p > 0.05 es Normal. Con  p value 0.32, 0.31 y 0,31 se verifica Normalidad.

# %%
print("Shapiro fert1:", shapiro(fertilizer_1))
print("Shapiro fert2:", shapiro(fertilizer_2))
print("Shapiro fert3:", shapiro(fertilizer_3))
# Out:
# Shapiro fert1: ShapiroResult(statistic=np.float64(0.8834906936019853), pvalue=np.float64(0.32542950716414576))
# Shapiro fert2: ShapiroResult(statistic=np.float64(0.8810376385817489), pvalue=np.float64(0.3140395561440371))
# Shapiro fert3: ShapiroResult(statistic=np.float64(0.8810376385817489), pvalue=np.float64(0.3140395561440371))

# %% [markdown]
# ## Homogeneidad de Varianzas. Si p > 0.05 se cumple la Homogeneidad. Con p value 0.80 se verifica la Homogeneidad de Varianzas.

# %%
print("Levene:", levene(fertilizer_1, fertilizer_2, fertilizer_3))
# Out:
# Levene: LeveneResult(statistic=np.float64(0.22222222222222207), pvalue=np.float64(0.8039599174006208))

# %% [markdown]
# ## ANOVA Clásico. Si P  > 0.05 No hay diferencia significativa. Como es menor a 0.05 si hay diferencias entre los grupos.

# %%
f_value, p_value = f_oneway(fertilizer_1, fertilizer_2, fertilizer_3)
print("F:", f_value, "p:", p_value)
# Out:
# F: 20.31578947368421 p: 0.000140478247931904

# %% [markdown]
# ## Tukey . Si p > 0.05 No hay diferencia significativa. Todas son menores a 0.05.  En este caso Fert 3 es mayor a Fert 2, y Fert 2 es mayor a Fert 1. y Fert 3 es mayor a Fert 1. Por tanto Fert 3 es el produce mayor rendimiento.

# %%
data = np.array(fertilizer_1 + fertilizer_2 + fertilizer_3)
labels = ['Fert1']*5 + ['Fert2']*5 + ['Fert3']*5

tukey = pairwise_tukeyhsd(data, labels, alpha=0.05)
print(tukey)
# Out:
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2 meandiff p-adj  lower  upper  reject
# --------------------------------------------------
#  Fert1  Fert2      1.8 0.0099 0.4572 3.1428   True
#  Fert1  Fert3      3.2 0.0001 1.8572 4.5428   True
#  Fert2  Fert3      1.4 0.0409 0.0572 2.7428   True
# --------------------------------------------------
